# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import random
import csv
import os
import json
from tqdm import tqdm
import math
import altair as alt
import glob
#from scipy.stats import wasserstein_distance

# %% [markdown]
# ## Declares

# %%
TAG = "Chare2003"
DATA_DIRECTORY = os.path.join("..", "results", TAG)
JSONS_BS = glob.glob(os.path.join(DATA_DIRECTORY, "*.BUSTEDS.json"))
JSONS_BSMH = glob.glob(os.path.join(DATA_DIRECTORY, "*.BUSTEDS-MH.json"))
JSONS_BASE = glob.glob(os.path.join(DATA_DIRECTORY, "*.BUSTED.json"))
JSONS_BMH = glob.glob(os.path.join(DATA_DIRECTORY, "*.BUSTED-MH.json"))
# Create tables folder
OUTPUT_CSV = TAG + "-internal.csv"
ER_Threshold = 5
ER_Threshold_loose = 1
pval_Threshold = 0.05
Tests = 4

# %%
#define function to calculate cv
#cv = lambda x: np.std(x, ddof=1) / np.mean(x) * 100 
cv = lambda x: np.std(x) / np.mean(x)
pctchg = lambda a, b: (a / b) * 100


def read_json(filename):
    #print("# Reading:", filename)
    if os.stat(filename).st_size == 0: 
        print("# -- Error -- file is empty:", filename)
        return []
    #end if
    with open(filename, "r") as fh:
        json_data = json.load(fh)
    fh.close()
    return json_data
#end method

def convergence_issue(json_data):
    # For example if logL for a more complex model is LOWER than it is for a less complex model.
    convergence_issue = False 
    return ""
    """
    Constrained model
    MG94xREV with separate rates for branch sets
    Nucleotide GTR
    Unconstrained model
    """
    
    _models = ["Nucleotide GTR", 
                    "MG94xREV with separate rates for branch sets", 
                    "Constrained model", 
                    "Unconstrained model"]
    model_LL = {}
    
    for _model in _models:
        print(_model)
        _LL = json_data["fits"][_model]["Log Likelihood"]

        
    """
    return
    #Nucleotide_GTR = BS_data["fits"]["Nucleotide GTR"].get("Log Likelihood", 10)
    #MG94_REV = BS_data["fits"]["MG94xREV with separate rates for branch sets"].get("Log Likelihood",10)
    try:
        Constrained_model = BS_data["fits"]["Constrained model"].get("Log Likelihood", 10)
    except:
        Constrained_model = 10
    #end try
    Unconstrained_model = BS_data["fits"]["Unconstrained model"].get("Log Likelihood", 10)
    if Nucleotide_GTR < MG94_REV and MG94_REV < Constrained_model and Constrained_model < Unconstrained_model:
        pass
    else:
        issue = True
    #end if
    if issue == False:
        return ""
    else:
        return "ISSUE DETECTED"
    #end if
    """
#end method




def convergence_issue_old(BS_data):
    # For example if logL for a more complex model is LOWER than it is for a less complex model.
    convergence_issue = False 
    
    #Nucleotide_GTR = BS_data["fits"]["Nucleotide GTR"].get("Log Likelihood", 10)
    #MG94_REV = BS_data["fits"]["MG94xREV with separate rates for branch sets"].get("Log Likelihood",10)
    
    try:
        Constrained_model = BS_data["fits"]["Constrained model"].get("Log Likelihood", 10)
    except:
        Constrained_model = 10
    #end try
    
    Unconstrained_model = BS_data["fits"]["Unconstrained model"].get("Log Likelihood", 10)
    
    if Nucleotide_GTR < MG94_REV and MG94_REV < Constrained_model and Constrained_model < Unconstrained_model:
        pass
    else:
        issue = True
    #end if
    
    if issue == False:
        return ""
    else:
        return "ISSUE DETECTED"
    #end if
#end method

# %%
def process(FILES, fileending, method, pval_Threshold, Tests):
    df_dict = {}
    Bonferroni_pval = pval_Threshold / Tests
    for item in FILES:
        print("\t Processing:", item)
        basename = ""
        if fileending in os.path.basename(item):
             basename = os.path.basename(item).replace(fileending, "").replace(".best-gard", "")
             #basename = os.path.basename(item)
             #print("\t Basename:", basename)
        #end if
        for fext in [".phy", ".fasta", ".nex", "-align-dna.fas", "-Aligned-DNA.fas"]:
            basename = basename.replace(fext, "")
        #end for
        json_data = read_json(item) # Read json
        if json_data == []:
            continue # Empty file
        #end if
        df_dict[basename] = {"Method": method}
        df_dict[basename].update({"Sequences": json_data["input"]["number of sequences"]})
        df_dict[basename].update({"Codons": json_data["input"]["number of sites"]})
        df_dict[basename].update({"LRT p-value": json_data["test results"]["p-value"]})
        df_dict[basename].update({"Bonferroni p-value": Bonferroni_pval})
        Bonferroni_sig = False
        if json_data["test results"]["p-value"] <= Bonferroni_pval:
            Bonferroni_sig = True
        #end if
        # Bonferroni Test
        df_dict[basename].update({"Bonferroni significant": str(Bonferroni_sig)})
        # cAIC
        df_dict[basename].update({"cAIC": json_data["fits"]["Unconstrained model"]["AIC-c"]})
        #Omegas and proportions
        data = json_data["fits"]["Unconstrained model"]["Rate Distributions"]["Test"]
        w1 = data["0"]["omega"]
        p1 = data["0"]["proportion"]
        w2 = data["1"]["omega"]
        p2 = data["1"]["proportion"]
        w3 = data["2"]["omega"]
        p3 = data["2"]["proportion"]
        df_dict[basename].update({"w1": w1, "p1": p1})
        df_dict[basename].update({"w2": w2, "p2": p2})
        df_dict[basename].update({"w3": w3, "p3": p3})
        # SRV rates and proportions
        if method == "BUSTEDS-MH" or method == "BUSTEDS":
            data = json_data["fits"]["Unconstrained model"]["Rate Distributions"]["Synonymous site-to-site rates"]
            s1 = data["0"]["rate"]
            s_p1 = data["0"]["proportion"]
            s2 = data["1"]["rate"]
            s_p2 = data["1"]["proportion"]
            s3 = data["2"]["rate"]
            s_p3 = data["2"]["proportion"]
            df_dict[basename].update({"SRV1": s1, "SRV_p1": s_p1})
            df_dict[basename].update({"SRV2": s2, "SRV_p2": s_p2})
            df_dict[basename].update({"SRV3": s3, "SRV_p3": s_p3})
        #end if
        # DH rate, TH rate, TH_SI rate
        if method == "BUSTEDS-MH" or method == "BUSTED-MH":
            df_dict[basename].update({"DH_Rate": float(json_data["fits"]["Unconstrained model"]["Rate Distributions"]["rate at which 2 nucleotides are changed instantly within a single codon"])})
            df_dict[basename].update({"TH_Rate": float(json_data["fits"]["Unconstrained model"]["Rate Distributions"]["rate at which 3 nucleotides are changed instantly within a single codon"])})
            #df_dict[basename].update({"TH_Rate_SI": float(json_data["fits"]["Unconstrained model"]["rate at which 3 nucleotides are changed instantly within a single codon between synonymous codon islands"])})
        #end if
        # Convergence issues check
        df_dict[basename].update({"Convergence_Issue": convergence_issue(json_data)})
    # end for
    df = pd.DataFrame.from_dict(df_dict, orient="index")
    df = df.reset_index()
    df.index += 1
    df.rename(columns={'index': 'Gene'}, inplace = True)
    return df
#end method

# %% [markdown]
# ## Process

# %%
print("# Processing BUSTED[S] files")
df_BUSTEDS = process(JSONS_BS , ".BUSTEDS.json", "BUSTEDS", pval_Threshold, Tests)
print("\n# Processing BUSTED[S]-MH files")
df_BUSTEDS_MH = process(JSONS_BSMH, ".BUSTEDS-MH.json", "BUSTEDS-MH", pval_Threshold, Tests)
print("\n# Processing BUSTED files")
df_BUSTED = process(JSONS_BASE , ".BUSTED.json", "BUSTED", pval_Threshold, Tests)
print("\n# Processing BUSTED-MH files")
df_BUSTED_MH = process(JSONS_BMH, ".BUSTED-MH.json", "BUSTED-MH", pval_Threshold, Tests)
# Out:
# # Processing BUSTED[S] files
# 	 Processing: ..\results\Chare2003\Akabane_virus_NP.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Avian_pneumovirus_F.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Avian_pneumovirus_M.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Avian_pneumovirus_N.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Avian_pneumovirus_P.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Borna_disease_virus_G.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Borna_disease_virus_M.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Borna_disease_virus_NP.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Bovine_respiratory_syncytial_virus_G.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Cache_Valley_Virus_G.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Canine_distemper_virus_F.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Canine_distemper_virus_H.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Crimean_Congo_hemorrhagic_fever_virus_G.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Crimean_Congo_hemorrhagic_fever_virus_NP.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Dobrava_virus_N.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Guanarito.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Hantaan_virus_G2.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Hantaan_virus_N.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Human_parainfluenza_virus_1_HN.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Human_parainfluenza_virus_3_HN.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Human_respiratory_syncytial_virus_A_G.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Human_respiratory_syncytial_virus_A_N.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Human_respiratory_syncytial_virus_B_G.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Infectious_hematopoietic_virus_G.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Influenza_A_virus_equine_H3N8.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Influenza_A_virus_human_H1N1.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Influenza_A_virus_human_H2N2.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Influenza_A_virus_human_H3N2.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Influenza_A_virus_human_swine_avian_H1N1.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Influenza_A_virus_human_swine_avian_H1N1star.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Influenza_A_virus_swine_H1N1.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Influenza_B_virus_HA.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Influenza_B_virus_M.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Influenza_B_virus_NA.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Influenza_B_virus_NP.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Influenza_B_virus_PA.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Influenza_C_virus_CM2.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Influenza_C_virus_NP.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Junin.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\LCMV.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\La_Crosse_Virus_G.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Lassa.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Measles_virus_F.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Measles_virus_HA.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Measles_virus_L.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Measles_virus_N_part1.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Measles_virus_N_part2.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Mumps_virus_F.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Mumps_virus_HN.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Mumps_virus_M.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Newcastle_disease_virus_F.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Newcastle_disease_virus_HN.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Newcastle_disease_virus_M.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Newcastle_disease_virus_N.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Newcastle_disease_virus_P.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Oropouche_virus_NP.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Puumala_virus_G1.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Puumala_virus_G2.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Puumala_virus_NP.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Rabies_virus_G.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Rabies_virus_N.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Rice_stripe_Virus_JN.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Rift_Valley_Fever_Virus_G2.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Sendai_virus_F.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Sendai_virus_M.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Sendai_virus_NP.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Sin_Nombre_virus_N.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Tomato_spotted_wilt_virus_NSS.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Vesicular_stomatitis_Indiana_virus_G.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Vesicular_stomatitis_virus_G.nex.BUSTEDS.json
# 	 Processing: ..\results\Chare2003\Viral_hemorrhagic_septicaemia_virus_N.nex.BUSTEDS.json
#
# # Processing BUSTED[S]-MH files
# 	 Processing: ..\results\Chare2003\Akabane_virus_NP.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Avian_pneumovirus_F.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Avian_pneumovirus_M.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Avian_pneumovirus_N.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Avian_pneumovirus_P.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Borna_disease_virus_G.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Borna_disease_virus_M.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Borna_disease_virus_NP.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Bovine_respiratory_syncytial_virus_G.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Cache_Valley_Virus_G.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Canine_distemper_virus_F.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Canine_distemper_virus_H.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Crimean_Congo_hemorrhagic_fever_virus_G.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Crimean_Congo_hemorrhagic_fever_virus_NP.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Dobrava_virus_N.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Guanarito.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Hantaan_virus_G2.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Hantaan_virus_N.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Human_parainfluenza_virus_1_HN.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Human_parainfluenza_virus_3_HN.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Human_respiratory_syncytial_virus_A_G.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Human_respiratory_syncytial_virus_A_N.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Human_respiratory_syncytial_virus_B_G.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Infectious_hematopoietic_virus_G.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Influenza_A_virus_equine_H3N8.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Influenza_A_virus_human_H1N1.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Influenza_A_virus_human_H2N2.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Influenza_A_virus_human_H3N2.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Influenza_A_virus_human_swine_avian_H1N1.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Influenza_A_virus_human_swine_avian_H1N1star.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Influenza_A_virus_swine_H1N1.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Influenza_B_virus_HA.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Influenza_B_virus_M.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Influenza_B_virus_NA.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Influenza_B_virus_NP.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Influenza_B_virus_PA.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Influenza_C_virus_CM2.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Influenza_C_virus_NP.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Junin.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\LCMV.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\La_Crosse_Virus_G.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Lassa.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Measles_virus_F.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Measles_virus_HA.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Measles_virus_L.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Measles_virus_N_part1.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Measles_virus_N_part2.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Mumps_virus_F.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Mumps_virus_HN.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Mumps_virus_M.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Newcastle_disease_virus_F.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Newcastle_disease_virus_HN.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Newcastle_disease_virus_M.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Newcastle_disease_virus_N.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Newcastle_disease_virus_P.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Oropouche_virus_NP.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Puumala_virus_G1.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Puumala_virus_G2.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Puumala_virus_NP.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Rabies_virus_G.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Rabies_virus_N.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Rice_stripe_Virus_JN.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Rift_Valley_Fever_Virus_G2.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Sendai_virus_F.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Sendai_virus_M.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Sendai_virus_NP.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Sin_Nombre_virus_N.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Tomato_spotted_wilt_virus_NSS.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Vesicular_stomatitis_Indiana_virus_G.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Vesicular_stomatitis_virus_G.nex.BUSTEDS-MH.json
# 	 Processing: ..\results\Chare2003\Viral_hemorrhagic_septicaemia_virus_N.nex.BUSTEDS-MH.json
#
# # Processing BUSTED files
# 	 Processing: ..\results\Chare2003\Akabane_virus_NP.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Avian_pneumovirus_F.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Avian_pneumovirus_M.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Avian_pneumovirus_N.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Avian_pneumovirus_P.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Borna_disease_virus_G.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Borna_disease_virus_M.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Borna_disease_virus_NP.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Bovine_respiratory_syncytial_virus_G.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Cache_Valley_Virus_G.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Canine_distemper_virus_F.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Canine_distemper_virus_H.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Crimean_Congo_hemorrhagic_fever_virus_G.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Crimean_Congo_hemorrhagic_fever_virus_NP.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Dobrava_virus_N.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Guanarito.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Hantaan_virus_G2.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Hantaan_virus_N.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Human_parainfluenza_virus_1_HN.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Human_parainfluenza_virus_3_HN.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Human_respiratory_syncytial_virus_A_G.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Human_respiratory_syncytial_virus_A_N.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Human_respiratory_syncytial_virus_B_G.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Infectious_hematopoietic_virus_G.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Influenza_A_virus_equine_H3N8.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Influenza_A_virus_human_H1N1.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Influenza_A_virus_human_H2N2.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Influenza_A_virus_human_H3N2.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Influenza_A_virus_human_swine_avian_H1N1.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Influenza_A_virus_human_swine_avian_H1N1star.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Influenza_A_virus_swine_H1N1.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Influenza_B_virus_HA.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Influenza_B_virus_M.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Influenza_B_virus_NA.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Influenza_B_virus_NP.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Influenza_B_virus_PA.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Influenza_C_virus_CM2.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Influenza_C_virus_NP.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Junin.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\LCMV.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\La_Crosse_Virus_G.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Lassa.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Measles_virus_F.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Measles_virus_HA.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Measles_virus_L.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Measles_virus_N_part1.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Measles_virus_N_part2.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Mumps_virus_F.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Mumps_virus_HN.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Mumps_virus_M.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Newcastle_disease_virus_F.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Newcastle_disease_virus_HN.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Newcastle_disease_virus_M.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Newcastle_disease_virus_N.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Newcastle_disease_virus_P.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Oropouche_virus_NP.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Puumala_virus_G1.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Puumala_virus_G2.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Puumala_virus_NP.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Rabies_virus_G.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Rabies_virus_N.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Rice_stripe_Virus_JN.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Rift_Valley_Fever_Virus_G2.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Sendai_virus_F.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Sendai_virus_M.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Sendai_virus_NP.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Sin_Nombre_virus_N.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Tomato_spotted_wilt_virus_NSS.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Vesicular_stomatitis_Indiana_virus_G.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Vesicular_stomatitis_virus_G.nex.BUSTED.json
# 	 Processing: ..\results\Chare2003\Viral_hemorrhagic_septicaemia_virus_N.nex.BUSTED.json
#
# # Processing BUSTED-MH files
# 	 Processing: ..\results\Chare2003\Akabane_virus_NP.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Avian_pneumovirus_F.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Avian_pneumovirus_M.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Avian_pneumovirus_N.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Avian_pneumovirus_P.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Borna_disease_virus_G.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Borna_disease_virus_M.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Borna_disease_virus_NP.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Bovine_respiratory_syncytial_virus_G.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Cache_Valley_Virus_G.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Canine_distemper_virus_F.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Canine_distemper_virus_H.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Crimean_Congo_hemorrhagic_fever_virus_G.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Crimean_Congo_hemorrhagic_fever_virus_NP.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Dobrava_virus_N.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Guanarito.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Hantaan_virus_G2.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Hantaan_virus_N.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Human_parainfluenza_virus_1_HN.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Human_parainfluenza_virus_3_HN.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Human_respiratory_syncytial_virus_A_G.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Human_respiratory_syncytial_virus_A_N.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Human_respiratory_syncytial_virus_B_G.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Infectious_hematopoietic_virus_G.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Influenza_A_virus_equine_H3N8.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Influenza_A_virus_human_H1N1.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Influenza_A_virus_human_H2N2.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Influenza_A_virus_human_H3N2.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Influenza_A_virus_human_swine_avian_H1N1.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Influenza_A_virus_human_swine_avian_H1N1star.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Influenza_A_virus_swine_H1N1.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Influenza_B_virus_HA.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Influenza_B_virus_M.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Influenza_B_virus_NA.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Influenza_B_virus_NP.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Influenza_B_virus_PA.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Influenza_C_virus_CM2.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Influenza_C_virus_NP.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Junin.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\LCMV.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\La_Crosse_Virus_G.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Lassa.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Measles_virus_F.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Measles_virus_HA.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Measles_virus_L.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Measles_virus_N_part1.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Measles_virus_N_part2.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Mumps_virus_F.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Mumps_virus_HN.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Mumps_virus_M.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Newcastle_disease_virus_F.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Newcastle_disease_virus_HN.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Newcastle_disease_virus_M.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Newcastle_disease_virus_N.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Newcastle_disease_virus_P.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Oropouche_virus_NP.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Puumala_virus_G1.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Puumala_virus_G2.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Puumala_virus_NP.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Rabies_virus_G.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Rabies_virus_N.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Rice_stripe_Virus_JN.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Rift_Valley_Fever_Virus_G2.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Sendai_virus_F.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Sendai_virus_M.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Sendai_virus_NP.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Sin_Nombre_virus_N.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Tomato_spotted_wilt_virus_NSS.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Vesicular_stomatitis_Indiana_virus_G.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Vesicular_stomatitis_virus_G.nex.BUSTED-MH.json
# 	 Processing: ..\results\Chare2003\Viral_hemorrhagic_septicaemia_virus_N.nex.BUSTED-MH.json

# %% [markdown]
# ## Concatenate tables

# %%
result = pd.concat([df_BUSTEDS, df_BUSTEDS_MH, df_BUSTED, df_BUSTED_MH])
result = result.fillna("")
result = result.sort_values(by=["Gene", "Method"], ascending=True)
result = result.reset_index(drop=True)
result.index += 1
result
# Out:
#                                       Gene      Method  Sequences  Codons  \
# 1                         Akabane_virus_NP      BUSTED         26     233
# 2                         Akabane_virus_NP   BUSTED-MH         26     233
# 3                         Akabane_virus_NP     BUSTEDS         26     233
# 4                         Akabane_virus_NP  BUSTEDS-MH         26     233
# 5                      Avian_pneumovirus_F      BUSTED         14     532
# ..                                     ...         ...        ...     ...
# 280           Vesicular_stomatitis_virus_G  BUSTEDS-MH         25     508
# 281  Viral_hemorrhagic_septicaemia_virus_N      BUSTED         10     404
# 282  Viral_hemorrhagic_septicaemia_virus_N   BUSTED-MH         10     404
# 283  Viral_hemorrhagic_septicaemia_virus_N     BUSTEDS         10     404
# 284  Viral_hemorrhagic_septicaemia_virus_N  BUSTEDS-MH         10     404
#
#      LRT p-value  Bonferroni p-value Bonferroni significant         cAIC  \
# 1       0.500000              0.0125                  False  2888.870521
# 2       0.500000              0.0125                  False  2892.951388
# 3       0.500000              0.0125                  False  2875.584537
# 4       0.500000              0.0125                  False  2879.686437
# 5       0.467214              0.0125                  False  5711.861700
# ..           ...                 ...                    ...          ...
# 280     0.500000              0.0125                  False  9886.225081
# 281     0.019947              0.0125                  False  5149.764185
# 282     0.085759              0.0125                  False  5152.805703
# 283     0.068787              0.0125                  False  5150.977953
# 284     0.095999              0.0125                  False  5154.995188
#
#            w1        p1  ...        p3      SRV1    SRV_p1      SRV2  \
# 1    0.000000  0.959943  ...  0.040057
# 2    0.023882  0.686470  ...  0.000000
# 3    0.007221  0.446206  ...  0.000000       0.0  0.559922  2.272175
# 4    0.010860  0.000000  ...  0.000000       0.0  0.559947  2.270568
# 5    0.000000  0.709590  ...  0.046745
# ..        ...       ...  ...       ...       ...       ...       ...
# 280  0.029742  0.368226  ...  0.000000  0.099005  0.126811  0.536728
# 281  0.000012  0.969760  ...  0.022948
# 282  0.001026  0.817391  ...  0.022209
# 283  0.053406  0.938035  ...  0.027383       0.0  0.138079  0.742201
# 284  0.074921  0.959330  ...  0.022736       0.0  0.137658  0.745772
#
#        SRV_p2      SRV3    SRV_p3 Convergence_Issue   DH_Rate TH_Rate
# 1
# 2                                                    0.301108     0.0
# 3    0.078226  2.272357  0.361852
# 4    0.041192  2.272646  0.398861                         0.0     0.0
# 5
# ..        ...       ...       ...               ...       ...     ...
# 280       0.0  1.130849  0.873189                         0.0     0.0
# 281
# 282                                                  0.057413     0.0
# 283  0.719609  3.273835  0.142312
# 284  0.720301  3.258368   0.14204                    0.022394     0.0
#
# [284 rows x 23 columns]

# %% [markdown]
# ## Calculate AIC weighted p-values

# %%
df_main_holder = []
for gene in set(result["Gene"].tolist()):
    print(gene)
    df_holder = result[result["Gene"] == gene]
    min_cAIC = min(df_holder["cAIC"].tolist())
    print("\tBest cAIC is:", min_cAIC)
    averaged = {}
    for index, row in df_holder.iterrows():
        method = row["Method"]
        cAIC   = row["cAIC"]
        pvalue = row["LRT p-value"]
        weight = math.exp (-0.5 * (cAIC - min_cAIC))
        if cAIC == min_cAIC:
            print("\tBest method:", method)
        #end if
        averaged[method] = {
                            "weight": weight,
                            "original_pval": pvalue
        }
    #end for
    weight_sum = 0
    for method in averaged.keys():
        weight_sum += averaged[method]["weight"]
    #end for
    for method in averaged.keys():
        averaged[method]["normalized_weighted"] = averaged[method]["weight"] / weight_sum
    #end for
    #calculate p_ma
    p_ma = 0
    for method in averaged.keys():
        p_ma += averaged[method]["original_pval"] * averaged[method]["normalized_weighted"]
    #end for
    print("p_ma is:", p_ma)
    df_holder["p_value_averaged"] = p_ma
    df_main_holder.append(df_holder)
#end for

result = pd.concat(df_main_holder)
result = result.fillna("")
result = result.sort_values(by=["Gene", "Method"], ascending=True)
result = result.reset_index(drop=True)
result.index += 1
# Out:
# Borna_disease_virus_M
# 	Best cAIC is: 1991.103585432979
# 	Best method: BUSTED
# p_ma is: 0.49999999999999983
# Mumps_virus_HN
# 	Best cAIC is: 8237.13478695954
# 	Best method: BUSTEDS
# p_ma is: 0.5
# Avian_pneumovirus_M
# 	Best cAIC is: 3205.649012093544
# 	Best method: BUSTEDS
# p_ma is: 0.2503546523564161
# Measles_virus_HA
# 	Best cAIC is: 8409.855720381602
# 	Best method: BUSTED
# p_ma is: 0.5
# Oropouche_virus_NP
# 	Best cAIC is: 3403.678263027118
# 	Best method: BUSTEDS
# p_ma is: 0.003492078950385747
# Mumps_virus_F
# 	Best cAIC is: 9664.083867912257
# 	Best method: BUSTEDS
# p_ma is: 0.4999999999999999
# Influenza_A_virus_human_H3N2
# 	Best cAIC is: 9085.118742408857
# 	Best method: BUSTEDS
# p_ma is: 0.5
# Rabies_virus_N
# 	Best cAIC is: 32026.29680334159
# 	Best method: BUSTEDS-MH
# p_ma is: 0.4999773898472658
# Newcastle_disease_virus_M
# 	Best cAIC is: 11989.79472343287
# 	Best method: BUSTEDS
# p_ma is: 0.4989611805095998
# Puumala_virus_G2
# 	Best cAIC is: 6782.402861649647
# 	Best method: BUSTEDS
# p_ma is: 0.49999999999999994
# Measles_virus_F
# 	Best cAIC is: 7580.623586869383
# 	Best method: BUSTED
# p_ma is: 0.5
# Influenza_B_virus_NP
# 	Best cAIC is: 8264.181914156565
# 	Best method: BUSTEDS
# p_ma is: 0.49999999973927634
# Rabies_virus_G
# 	Best cAIC is: 34685.93876645816
# 	Best method: BUSTEDS
# p_ma is: 0.5
# Puumala_virus_NP
# 	Best cAIC is: 19331.51391399752
# 	Best method: BUSTEDS
# p_ma is: 0.00825362033880966
# Influenza_B_virus_NA
# 	Best cAIC is: 7879.030671912629
# 	Best method: BUSTEDS
# p_ma is: 0.4999999999999999
# Avian_pneumovirus_N
# 	Best cAIC is: 3961.189040463122
# 	Best method: BUSTED
# p_ma is: 0.5
# Junin
# 	Best cAIC is: 3888.90242762342
# 	Best method: BUSTEDS
# p_ma is: 0.5000000000000001
# Influenza_A_virus_human_swine_avian_H1N1
# 	Best cAIC is: 18836.99699224061
# 	Best method: BUSTEDS
# p_ma is: 0.007286959810396454
# Influenza_A_virus_human_swine_avian_H1N1star
# 	Best cAIC is: 20188.80056123705
# 	Best method: BUSTEDS
# p_ma is: 6.121473001903172e-07
# Infectious_hematopoietic_virus_G
# 	Best cAIC is: 6359.656084644241
# 	Best method: BUSTEDS-MH
# p_ma is: 0.4999999989053264
# Canine_distemper_virus_H
# 	Best cAIC is: 14184.03547321747
# 	Best method: BUSTEDS
# p_ma is: 0.5
# Hantaan_virus_N
# 	Best cAIC is: 9321.987394365204
# 	Best method: BUSTEDS
# p_ma is: 0.5
# Rift_Valley_Fever_Virus_G2
# 	Best cAIC is: 3190.104473418624
# 	Best method: BUSTEDS
# p_ma is: 0.17622040927234964
# Crimean_Congo_hemorrhagic_fever_virus_G
# 	Best cAIC is: 29676.57470025438
# 	Best method: BUSTEDS
# p_ma is: 0.49999999824108277
# Hantaan_virus_G2
# 	Best cAIC is: 10654.17267301239
# 	Best method: BUSTEDS
# p_ma is: 0.5000000000000001
# Vesicular_stomatitis_virus_G
# 	Best cAIC is: 9881.151109464123
# 	Best method: BUSTED
# p_ma is: 0.5
# Sendai_virus_F
# 	Best cAIC is: 6628.09783895674
# 	Best method: BUSTED
# p_ma is: 2.894691942671156e-07
# Bovine_respiratory_syncytial_virus_G
# 	Best cAIC is: 4687.494056289017
# 	Best method: BUSTED
# p_ma is: 0.5
# Influenza_A_virus_swine_H1N1
# 	Best cAIC is: 9183.398002130578
# 	Best method: BUSTED
# p_ma is: 0.4996008422404578
# Influenza_A_virus_equine_H3N8
# 	Best cAIC is: 6922.271227322984
# 	Best method: BUSTEDS
# p_ma is: 0.48670083703053785
# Measles_virus_N_part2
# 	Best cAIC is: 11302.28867191791
# 	Best method: BUSTEDS
# p_ma is: 0.5
# Lassa
# 	Best cAIC is: 13167.47777354321
# 	Best method: BUSTEDS
# p_ma is: 0.49999999999999734
# Newcastle_disease_virus_HN
# 	Best cAIC is: 20149.92298251477
# 	Best method: BUSTEDS-MH
# p_ma is: 0.4437049895865144
# Sendai_virus_M
# 	Best cAIC is: 4222.671800077545
# 	Best method: BUSTED-MH
# p_ma is: 1.5083926912484795e-05
# Human_respiratory_syncytial_virus_B_G
# 	Best cAIC is: 4520.072954262485
# 	Best method: BUSTEDS
# p_ma is: 0.35368995269861603
# Human_parainfluenza_virus_3_HN
# 	Best cAIC is: 7102.103249341741
# 	Best method: BUSTEDS
# p_ma is: 0.5
# LCMV
# 	Best cAIC is: 6286.375378064819
# 	Best method: BUSTEDS
# p_ma is: 0.04174442385599567
# Avian_pneumovirus_F
# 	Best cAIC is: 5711.861700193325
# 	Best method: BUSTED
# p_ma is: 0.4671230220774943
# Vesicular_stomatitis_Indiana_virus_G
# 	Best cAIC is: 7871.025390062182
# 	Best method: BUSTED
# p_ma is: 0.49994576118794826
# Influenza_B_virus_HA
# 	Best cAIC is: 7277.233870940452
# 	Best method: BUSTEDS
# p_ma is: 0.07885637961661418
# Influenza_B_virus_M
# 	Best cAIC is: 3285.092658628449
# 	Best method: BUSTED
# p_ma is: 0.49999999999999994
# Viral_hemorrhagic_septicaemia_virus_N
# 	Best cAIC is: 5149.764184785186
# 	Best method: BUSTED
# p_ma is: 0.04529943796536964
# Influenza_B_virus_PA
# 	Best cAIC is: 9487.240140648388
# 	Best method: BUSTED
# p_ma is: 0.4985731619480192
# Human_respiratory_syncytial_virus_A_N
# 	Best cAIC is: 6829.485483427541
# 	Best method: BUSTED
# p_ma is: 0.49999999999999994
# Borna_disease_virus_NP
# 	Best cAIC is: 5314.982916759765
# 	Best method: BUSTEDS
# p_ma is: 0.4983073803496405
# Mumps_virus_M
# 	Best cAIC is: 4067.369990581066
# 	Best method: BUSTED
# p_ma is: 0.5
# Influenza_A_virus_human_H1N1
# 	Best cAIC is: 8515.755147163565
# 	Best method: BUSTEDS
# p_ma is: 0.4876724560935365
# Human_parainfluenza_virus_1_HN
# 	Best cAIC is: 9126.420806983913
# 	Best method: BUSTEDS
# p_ma is: 0.49999999999999994
# Influenza_C_virus_NP
# 	Best cAIC is: 2768.294043755039
# 	Best method: BUSTEDS
# p_ma is: 0.24876690834684945
# Newcastle_disease_virus_F
# 	Best cAIC is: 16916.80296159304
# 	Best method: BUSTEDS
# p_ma is: 0.49974700563085167
# Measles_virus_N_part1
# 	Best cAIC is: 17676.23798398771
# 	Best method: BUSTEDS-MH
# p_ma is: 0.4960710966067474
# Canine_distemper_virus_F
# 	Best cAIC is: 3980.107412826814
# 	Best method: BUSTED
# p_ma is: 0.21896415237900263
# Borna_disease_virus_G
# 	Best cAIC is: 7669.179811368921
# 	Best method: BUSTEDS
# p_ma is: 0.5000000000000001
# Newcastle_disease_virus_P
# 	Best cAIC is: 14952.76700635101
# 	Best method: BUSTEDS-MH
# p_ma is: 0.5
# Avian_pneumovirus_P
# 	Best cAIC is: 3711.370007683632
# 	Best method: BUSTED
# p_ma is: 0.5
# Measles_virus_L
# 	Best cAIC is: 26219.56133359664
# 	Best method: BUSTEDS
# p_ma is: 0.5
# Sin_Nombre_virus_N
# 	Best cAIC is: 1820.350609990872
# 	Best method: BUSTEDS
# p_ma is: 0.5
# Akabane_virus_NP
# 	Best cAIC is: 2875.584536759167
# 	Best method: BUSTEDS
# p_ma is: 0.5
# Tomato_spotted_wilt_virus_NSS
# 	Best cAIC is: 5514.272360599456
# 	Best method: BUSTED
# p_ma is: 0.5000000000000001
# Cache_Valley_Virus_G
# 	Best cAIC is: 11491.17626988299
# 	Best method: BUSTEDS
# p_ma is: 0.5
# Influenza_C_virus_CM2
# 	Best cAIC is: 3894.128293233729
# 	Best method: BUSTED
# p_ma is: 0.5
# La_Crosse_Virus_G
# 	Best cAIC is: 17072.66192270183
# 	Best method: BUSTEDS
# p_ma is: 0.5
# Crimean_Congo_hemorrhagic_fever_virus_NP
# 	Best cAIC is: 11466.07111627787
# 	Best method: BUSTEDS-MH
# p_ma is: 0.5
# Newcastle_disease_virus_N
# 	Best cAIC is: 13437.8218360955
# 	Best method: BUSTEDS
# p_ma is: 0.48723026099834144
# Influenza_A_virus_human_H2N2
# 	Best cAIC is: 11421.93992282408
# 	Best method: BUSTEDS
# p_ma is: 0.3863104622645708
# Rice_stripe_Virus_JN
# 	Best cAIC is: 2155.116719396759
# 	Best method: BUSTED
# p_ma is: 0.5000000000000001
# Sendai_virus_NP
# 	Best cAIC is: 6062.352124424548
# 	Best method: BUSTED-MH
# p_ma is: 0.0018078559675294894
# Puumala_virus_G1
# 	Best cAIC is: 19088.01666585847
# 	Best method: BUSTEDS
# p_ma is: 0.038092075857803984
# Dobrava_virus_N
# 	Best cAIC is: 3596.394380337113
# 	Best method: BUSTED
# p_ma is: 0.5
# Guanarito
# 	Best cAIC is: 5255.213293403433
# 	Best method: BUSTEDS
# p_ma is: 0.04095593115046757
# Human_respiratory_syncytial_virus_A_G
# 	Best cAIC is: 9410.957208754526
# 	Best method: BUSTEDS
# p_ma is: 0.15611127154335752
# <ipython-input-71-c475882cb403>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_holder["p_value_averaged"] = p_ma

# %%
result
# Out:
#                                       Gene      Method  Sequences  Codons  \
# 1                         Akabane_virus_NP      BUSTED         26     233
# 2                         Akabane_virus_NP   BUSTED-MH         26     233
# 3                         Akabane_virus_NP     BUSTEDS         26     233
# 4                         Akabane_virus_NP  BUSTEDS-MH         26     233
# 5                      Avian_pneumovirus_F      BUSTED         14     532
# ..                                     ...         ...        ...     ...
# 280           Vesicular_stomatitis_virus_G  BUSTEDS-MH         25     508
# 281  Viral_hemorrhagic_septicaemia_virus_N      BUSTED         10     404
# 282  Viral_hemorrhagic_septicaemia_virus_N   BUSTED-MH         10     404
# 283  Viral_hemorrhagic_septicaemia_virus_N     BUSTEDS         10     404
# 284  Viral_hemorrhagic_septicaemia_virus_N  BUSTEDS-MH         10     404
#
#      LRT p-value  Bonferroni p-value Bonferroni significant         cAIC  \
# 1       0.500000              0.0125                  False  2888.870521
# 2       0.500000              0.0125                  False  2892.951388
# 3       0.500000              0.0125                  False  2875.584537
# 4       0.500000              0.0125                  False  2879.686437
# 5       0.467214              0.0125                  False  5711.861700
# ..           ...                 ...                    ...          ...
# 280     0.500000              0.0125                  False  9886.225081
# 281     0.019947              0.0125                  False  5149.764185
# 282     0.085759              0.0125                  False  5152.805703
# 283     0.068787              0.0125                  False  5150.977953
# 284     0.095999              0.0125                  False  5154.995188
#
#            w1        p1  ...      SRV1    SRV_p1      SRV2    SRV_p2  \
# 1    0.000000  0.959943  ...
# 2    0.023882  0.686470  ...
# 3    0.007221  0.446206  ...       0.0  0.559922  2.272175  0.078226
# 4    0.010860  0.000000  ...       0.0  0.559947  2.270568  0.041192
# 5    0.000000  0.709590  ...
# ..        ...       ...  ...       ...       ...       ...       ...
# 280  0.029742  0.368226  ...  0.099005  0.126811  0.536728       0.0
# 281  0.000012  0.969760  ...
# 282  0.001026  0.817391  ...
# 283  0.053406  0.938035  ...       0.0  0.138079  0.742201  0.719609
# 284  0.074921  0.959330  ...       0.0  0.137658  0.745772  0.720301
#
#          SRV3    SRV_p3 Convergence_Issue   DH_Rate TH_Rate p_value_averaged
# 1                                                                   0.500000
# 2                                          0.301108     0.0         0.500000
# 3    2.272357  0.361852                                             0.500000
# 4    2.272646  0.398861                         0.0     0.0         0.500000
# 5                                                                   0.467123
# ..        ...       ...               ...       ...     ...              ...
# 280  1.130849  0.873189                         0.0     0.0         0.500000
# 281                                                                 0.045299
# 282                                        0.057413     0.0         0.045299
# 283  3.273835  0.142312                                             0.045299
# 284  3.258368   0.14204                    0.022394     0.0         0.045299
#
# [284 rows x 24 columns]

# %%
#for method in averaged.keys():
#    averaged[method]["normalized_weighted"] = 
averaged
# Out:
# {'BUSTED': {'weight': 1.4462851330966086e-18,
#   'original_pval': 0.02449109781438102,
#   'normalized_weighted': 1.26209300157513e-18},
#  'BUSTED-MH': {'weight': 8.096061620101946e-19,
#   'original_pval': 0.1101119870234489,
#   'normalized_weighted': 7.064984958515186e-19},
#  'BUSTEDS': {'weight': 1.0,
#   'original_pval': 0.1555242873741191,
#   'normalized_weighted': 0.872644662310046},
#  'BUSTEDS-MH': {'weight': 0.14594180562890485,
#   'original_pval': 0.1601333142110422,
#   'normalized_weighted': 0.12735533768995405}}

# %%
df_holder = []

for g in set(result["Gene"].to_list()):
    #print(g)
    df_subset = result[result["Gene"] == g]
    df_subset["Annotation"] = ""
    min_cAIC = min(df_subset["cAIC"].to_list())
    if len(df_subset["cAIC"].to_list()) > 1:
        second_smallest = sorted(df_subset["cAIC"].to_list())[1]
    else:
        second_mallest = 0
    #end if
    for index, row in df_subset.iterrows():
        caic = row["cAIC"]
        if caic == min_cAIC:
            if second_smallest - caic > 5:
                df_subset["Annotation"][index] = "Strongly Preferred"
            else:
                df_subset["Annotation"][index] = "Preferred"
        #end if
    #end for
    df_holder.append(df_subset)
#end for
df_main = pd.concat(df_holder)
df_main = df_main.reset_index(drop=True)
df_main.index += 1
#df_main
# Out:
# <ipython-input-74-7560d6fdb3d2>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset["Annotation"] = ""
# <ipython-input-74-7560d6fdb3d2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset["Annotation"][index] = "Strongly Preferred"
# c:\python39\lib\site-packages\IPython\core\interactiveshell.py:3427: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# <ipython-input-74-7560d6fdb3d2>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset["Annotation"][index] = "Preferred"

# %% [markdown]
# ## Save table

# %%
#OUTPUT_CSV = "Ebola.csv"
#OUTPUT_CSV = "Zika.csv"
#OUTPUT_CSV = "Monkeypox.csv"
#OUTPUT_CSV = TAG + "-internal.csv"

print("Saving results to:", OUTPUT_CSV)
result.to_csv(OUTPUT_CSV, index=False)
# Out:
# Saving results to: Chare2003-internal.csv
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-75-56f14a0ce6aa> in <module>
#       5
#       6 print("Saving results to:", OUTPUT_CSV)
# ----> 7 result.to_csv(OUTPUT_CSV, index=False)
#
# c:\python39\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3384         )
#    3385
# -> 3386         return DataFrameRenderer(formatter).to_csv(
#    3387             path_or_buf,
#    3388             line_terminator=line_terminator,
#
# c:\python39\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# c:\python39\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     226         """
#     227         # apply compression and byte/text conversion
# --> 228         with get_handle(
#     229             self.filepath_or_buffer,
#     230             self.mode,
#
# c:\python39\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# PermissionError: [Errno 13] Permission denied: 'Chare2003-internal.csv'

# %%
gene_list = []
for item in df_main["Gene"].to_list():
    gene_list.append(item.split("_")[0])
gene_set = set(gene_list)
#gene_set

# %%
df_main["Group"] = ""
for index, row in df_main.iterrows():
    gene = row["Gene"]
    df_main["Group"][index] = str(gene.split("_")[0])
df_main
# Out:
# <ipython-input-77-f22282da0427>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_main["Group"][index] = str(gene.split("_")[0])
#                                       Gene      Method  Sequences  Codons  \
# 1                    Borna_disease_virus_M      BUSTED         19     142
# 2                    Borna_disease_virus_M   BUSTED-MH         19     142
# 3                    Borna_disease_virus_M     BUSTEDS         19     142
# 4                    Borna_disease_virus_M  BUSTEDS-MH         19     142
# 5                           Mumps_virus_HN      BUSTED         18     582
# ..                                     ...         ...        ...     ...
# 280                              Guanarito  BUSTEDS-MH         32     202
# 281  Human_respiratory_syncytial_virus_A_G      BUSTED         68     278
# 282  Human_respiratory_syncytial_virus_A_G   BUSTED-MH         68     278
# 283  Human_respiratory_syncytial_virus_A_G     BUSTEDS         68     278
# 284  Human_respiratory_syncytial_virus_A_G  BUSTEDS-MH         68     278
#
#      LRT p-value  Bonferroni p-value Bonferroni significant         cAIC  \
# 1       0.500000              0.0125                  False  1991.103585
# 2       0.500000              0.0125                  False  1996.104390
# 3       0.500000              0.0125                  False  2002.332746
# 4       0.500000              0.0125                  False  2005.727444
# 5       0.500000              0.0125                  False  8267.888096
# ..           ...                 ...                    ...          ...
# 280     0.040986              0.0125                  False  5259.287208
# 281     0.024491              0.0125                  False  9493.112276
# 282     0.110112              0.0125                  False  9494.272687
# 283     0.155524              0.0125                  False  9410.957209
# 284     0.160133              0.0125                  False  9414.806303
#
#            w1        p1  ...      SRV2    SRV_p2      SRV3    SRV_p3  \
# 1    0.029305  0.000000  ...
# 2    0.036027  0.974990  ...
# 3    0.014516  0.000000  ...       1.0       1.0  1.759124       0.0
# 4    0.035928  0.000000  ...  0.986777       0.0       1.0       1.0
# 5    0.110599  0.762196  ...
# ..        ...       ...  ...       ...       ...       ...       ...
# 280  0.000000  0.716597  ...  0.977293  0.350272  1.304349  0.504223
# 281  0.000000  0.516763  ...
# 282  0.001654  0.833211  ...
# 283  0.133947  0.564289  ...  1.342428  0.558549  4.810907  0.023201
# 284  0.022139  0.018518  ...  1.318446  0.572052  4.646647  0.025255
#
#     Convergence_Issue   DH_Rate TH_Rate p_value_averaged          Annotation  \
# 1                                               0.500000  Strongly Preferred
# 2                           0.0     0.0         0.500000
# 3                                               0.500000
# 4                           0.0     0.0         0.500000
# 5                                               0.500000
# ..                ...       ...     ...              ...                 ...
# 280                         0.0     0.0         0.040956
# 281                                             0.156111
# 282                    0.040445     0.0         0.156111
# 283                                             0.156111           Preferred
# 284                         0.0     0.0         0.156111
#
#          Group
# 1        Borna
# 2        Borna
# 3        Borna
# 4        Borna
# 5        Mumps
# ..         ...
# 280  Guanarito
# 281      Human
# 282      Human
# 283      Human
# 284      Human
#
# [284 rows x 26 columns]

# %% [markdown]
# ## Visualize

# %%
result = result.rename(columns={"LRT p-value": "p_value"})
df_main = df_main.rename(columns={"LRT p-value": "p_value"})

# %%
source = df_main
pval_threshold = 0.05 / Tests

heatmap = alt.Chart(source).mark_rect(opacity=0.9).encode(
    y = alt.Y('Gene'),
    x = alt.X('Method', axis=alt.Axis(labelAngle=-60)),
    color = alt.condition((alt.datum.p_value <= pval_threshold), 
                                alt.ColorValue('darkblue'), 
                                alt.ColorValue('lightgray')) 
).properties(
    width=600,
    height=1200
)

text = heatmap.mark_text().encode(
    text='Annotation:O',
    color=alt.value('white'))

chart = alt.layer(heatmap, text).configure_axis(
    labelFontSize=12,
    titleFontSize=12,
    labelLimit = 1000
).configure_scale(bandPaddingInner=0.05).properties(
    title=TAG+"-InternalBranches Genome Scan with BUSTED, LRT pValue threshold: " + str(pval_threshold))

chart
# Out:
# alt.LayerChart(...)

# %%
source = df_main

pval_threshold = 0.05

heatmap = alt.Chart(source).mark_rect(opacity=0.75).encode(
    y = alt.Y('Gene'),
    x = alt.X('Method', axis=alt.Axis(labelAngle=-60)),
    color = alt.condition((alt.datum.p_value_averaged <= pval_threshold), 
                                alt.ColorValue('darkblue'), 
                                alt.ColorValue('gray')) 
).properties(
    width=800,
    height=1200
)

text = heatmap.mark_text().encode(
    text='Annotation:O',
    color=alt.value('white'))

chart = alt.layer(heatmap, text).configure_axis(
    labelFontSize=12,
    titleFontSize=12,
    labelLimit = 1000
).configure_scale(bandPaddingInner=0.05).properties(
    title=TAG+" on Internal Branches Genome Scan with BUSTED, LRT p-value threshold: " + str(pval_threshold) + " on the AIC-weighted pvalue ")

chart
# Out:
# alt.LayerChart(...)

# %%
source = df_main

pval_threshold = 0.05

heatmap = alt.Chart(source).mark_rect(opacity=0.75).encode(
    y = alt.Y('Gene'),
    x = alt.X('Method', axis=alt.Axis(labelAngle=-60)),
    color = alt.condition((alt.datum.p_value_averaged <= pval_threshold), 
                                alt.ColorValue('darkblue'), 
                                alt.ColorValue('orange')),
).properties(
    width=800,
    height=1200
)

text = heatmap.mark_text().encode(
    text='Annotation:O',
    color=alt.value('white'))

chart = alt.layer(heatmap, text).encode(
).configure_axis(
    labelFontSize=12,
    titleFontSize=12,
    labelLimit = 1000,
).configure_scale(bandPaddingInner=0.05).properties(
    title=TAG+" on Internal Branches Genome Scan with BUSTED, LRT p-value threshold: " + str(pval_threshold) + " on the AIC-weighted pvalue ")

chart
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## End of file

# %%
df_main
# Out:
#                                       Gene      Method  Sequences  Codons  \
# 1                    Borna_disease_virus_M      BUSTED         19     142
# 2                    Borna_disease_virus_M   BUSTED-MH         19     142
# 3                    Borna_disease_virus_M     BUSTEDS         19     142
# 4                    Borna_disease_virus_M  BUSTEDS-MH         19     142
# 5                           Mumps_virus_HN      BUSTED         18     582
# ..                                     ...         ...        ...     ...
# 280                              Guanarito  BUSTEDS-MH         32     202
# 281  Human_respiratory_syncytial_virus_A_G      BUSTED         68     278
# 282  Human_respiratory_syncytial_virus_A_G   BUSTED-MH         68     278
# 283  Human_respiratory_syncytial_virus_A_G     BUSTEDS         68     278
# 284  Human_respiratory_syncytial_virus_A_G  BUSTEDS-MH         68     278
#
#       p_value  Bonferroni p-value Bonferroni significant         cAIC  \
# 1    0.500000              0.0125                  False  1991.103585
# 2    0.500000              0.0125                  False  1996.104390
# 3    0.500000              0.0125                  False  2002.332746
# 4    0.500000              0.0125                  False  2005.727444
# 5    0.500000              0.0125                  False  8267.888096
# ..        ...                 ...                    ...          ...
# 280  0.040986              0.0125                  False  5259.287208
# 281  0.024491              0.0125                  False  9493.112276
# 282  0.110112              0.0125                  False  9494.272687
# 283  0.155524              0.0125                  False  9410.957209
# 284  0.160133              0.0125                  False  9414.806303
#
#            w1        p1  ...      SRV2    SRV_p2      SRV3    SRV_p3  \
# 1    0.029305  0.000000  ...
# 2    0.036027  0.974990  ...
# 3    0.014516  0.000000  ...       1.0       1.0  1.759124       0.0
# 4    0.035928  0.000000  ...  0.986777       0.0       1.0       1.0
# 5    0.110599  0.762196  ...
# ..        ...       ...  ...       ...       ...       ...       ...
# 280  0.000000  0.716597  ...  0.977293  0.350272  1.304349  0.504223
# 281  0.000000  0.516763  ...
# 282  0.001654  0.833211  ...
# 283  0.133947  0.564289  ...  1.342428  0.558549  4.810907  0.023201
# 284  0.022139  0.018518  ...  1.318446  0.572052  4.646647  0.025255
#
#     Convergence_Issue   DH_Rate TH_Rate p_value_averaged          Annotation  \
# 1                                               0.500000  Strongly Preferred
# 2                           0.0     0.0         0.500000
# 3                                               0.500000
# 4                           0.0     0.0         0.500000
# 5                                               0.500000
# ..                ...       ...     ...              ...                 ...
# 280                         0.0     0.0         0.040956
# 281                                             0.156111
# 282                    0.040445     0.0         0.156111
# 283                                             0.156111           Preferred
# 284                         0.0     0.0         0.156111
#
#          Group
# 1        Borna
# 2        Borna
# 3        Borna
# 4        Borna
# 5        Mumps
# ..         ...
# 280  Guanarito
# 281      Human
# 282      Human
# 283      Human
# 284      Human
#
# [284 rows x 26 columns]

# %% [markdown]
# ## Go with this Viz

# %%
source = df_main
pval_threshold = 0.05 

heatmap = alt.Chart(source).mark_rect(opacity=0.9).encode(
    y = alt.Y('Gene'),
    x = alt.X('Method', axis=alt.Axis(labelAngle=-60)),
    color = alt.condition((alt.datum.p_value <= pval_threshold), 
                                alt.ColorValue('blue'), 
                                alt.ColorValue('lightgray')),
).properties(
    width=800,
    height=1200
)

text = heatmap.mark_text().encode(
    text='Annotation:O',
    color=alt.value('white'))


source["Averaged"] = source["p_value_averaged"]
source2 = source.copy()
source2["Method"] = "Averaged"

chart2 = alt.Chart(source2).mark_rect(opacity=0.9).encode(
    y = alt.Y('Gene'),
    x = alt.X('Method', axis=alt.Axis(labelAngle=-60)),         
    color = alt.condition((alt.datum.p_value_averaged <= pval_threshold), 
                                alt.ColorValue('darkblue'), 
                                alt.ColorValue('lightgray'))
).properties(
    width=200,
    height=1200
)

chart = alt.layer(heatmap,
                  text,
                  chart2).encode(
).configure_axis(
    labelFontSize=12,
    titleFontSize=12,
    labelLimit = 1000
).configure_scale(bandPaddingInner=0.05).properties(
    title=TAG+" on Internal Branches Genome Scan with BUSTED"
)

chart
# Out:
# alt.LayerChart(...)

# %%
source = df_main

pval_threshold = 0.05 

heatmap = alt.Chart(source).mark_rect(opacity=0.9).encode(
    y = alt.Y('Gene'),
    x = alt.X('Method', axis=alt.Axis(labelAngle=-60)),
    color = alt.condition((alt.datum.p_value <= pval_threshold), 
                                alt.ColorValue('blue'), 
                                alt.ColorValue('lightgray')),
).properties(
    width=200,
    height=200
).facet(
    'Group:N',
    columns = 6
)

#text = heatmap.mark_text().encode(
#    text='Annotation:O',
#    color=alt.value('white'))


#column=alt.Column("bins:O", 
#                      title=None, 
#                      header=alt.Header(labelFontSize=0)

#chart | chart2
source["Averaged"] = source["p_value_averaged"]
source2 = source.copy()
source2["Method"] = "Averaged"

chart2 = alt.Chart(source2).mark_rect(opacity=0.9).encode(
    y = alt.Y('Gene'),
    x = alt.X('Method', axis=alt.Axis(labelAngle=-60)),         
    color = alt.condition((alt.datum.p_value_averaged <= pval_threshold), 
                                alt.ColorValue('darkblue'), 
                                alt.ColorValue('lightgray'))
).properties(
    width=200,
    height=1200
)

#chart = alt.layer(heatmap, text).encode(
#).configure_axis(
#    labelFontSize=12,
#    titleFontSize=12,
#    labelLimit = 1000
#).configure_scale(bandPaddingInner=0.05).properties(
#    title=TAG+" on Internal Branches Genome Scan with BUSTED"
#)


heatmap
# Out:
# alt.FacetChart(...)
